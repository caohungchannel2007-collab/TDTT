# %%
#bài 2
n = int(input("nhập số nguyên n:"))
n%5==0 and n%10 != 0
# Out:
# False

# %%
n = int(input("nhập số nguyên n:"))
n%3==0 and n%5==0
# Out:
# False

# %%
a, b = map(float,input().split())
if a<b:
    print(b)
elif a>b:
    print(a)
else :
    print("2 số bằng nhau ")
# Out:
# 2 số bằng nhau

# %%
characters = ["không", "một", "hai", "ba", "bốn", "năm", "sáu", "bảy", "tám", "chín" ]
n = int(input("nhập số nguyên 0->9 :"))
print(characters[n])
# Out:
# sáu
