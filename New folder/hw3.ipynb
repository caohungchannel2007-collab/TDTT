# %% [markdown]
# W3A1

# %%
n = int(input())
hang_tram = n//100
hang_chuc = (n//10)%10
hang_donvi = (n%100)%10
dao_nguoc = hang_donvi*100 + hang_chuc*10 + hang_tram
print(dao_nguoc)
# Out:
# 543

# %% [markdown]
# W3A2

# %%
a, b = map(int,input().split())
a = a^b
b = b^a
a = a^b
print(f"a = {a}, b = {b}")
# Out:
# a = 4, b = 3

# %% [markdown]
# W3A3

# %%
n = int(input())
if n&(n-1)==0:
    print("chia het cho 2")
else:
    print("khong chia het")
# Out:
# khong chia het

# %% [markdown]
# W3A4

# %%
m,n = map(int,input().split())
x = m//n
print(x)
# Out:
# 1

# %% [markdown]
# W3A5

# %%
m,n = map(int,input().split())
if m/n <0 :
    x = m//n +1
    print(x)
elif m%n ==0:
    print(m/n)
else :
    x = m//n +1
    print(x)
# Out:
# 1

# %% [markdown]
# W3A8

# %%
a = input()
b = input()
if len(a)>len(b):
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# W3A10

# %%
a,b,c,d = map(int,input().split())
x = max(a,b,c,d)
print(x)
# Out:
# 6

# %% [markdown]
# W3A16

# %%
n = float(input())
if n<0:
    x = n+0.5
    print(f"{x:.0f}")
    print(int(n//1))
    print(f"{n:.0f}")
else:
    x = n+0.5
  
    print(f"{x:.0f}")
    print(int(n//1))
    print(f"{n:.0f}")
# Out:
# -6
# -7
# -7

# %% [markdown]
#     W3A17

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if b%a == 0:
     x = b/a
     if c*x==d and b*x == c:
          print("a,b,c,d are cap so nhan ")
     else:
      print("False")
else:
     print("False")
# Out:
# a,b,c,d are cap so nhan
