# %%
n = input("nhap vao so nguyen :")
don_vi = n[len(n)-1:None]
hang_nghin = n[len(n)-4:len(n)-3]
print("hang don vi la :",don_vi)
print("hang nghin la :", hang_nghin)
# Out:
# hang don vi la : 6
# hang nghin la : 3

# %%
# hoán đổi 2 số không sử dụng biến tạm thời 
# sử dụng phép toán XOR bitwise để hoán đổi giá trị của ha 
a, b = map(int,input().split())

# %%
#w3A3
n = int(input())
if n > 0 and n&(n-1)==0: 
 print(f"{n} la luy thua cua 2")
else:
 print("khong phai luy thua cua 2")
# Out:
# khong phai luy thua cua 2

# %%
n = float(input("nhap so thuc n:"))
k = int(input("lam tron den may chu so sau dau phay , ?"))
a = n*10**(k+1)
if a%10 >= 5 :
 b = n*10**(k)
 print("so thuc n la :", n)
 print((b//1+1)/(10**(k)))
else:
 b = n*10**(k)
 print("so thuc n la :", n)
 print((b//1)/(10**(k)))
# Out:
# so thuc n la : 1.1111
# 1.111
